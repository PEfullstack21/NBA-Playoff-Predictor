# %% [markdown]
# # Exploring Data with Pandas

# %%
import pandas as pd

df_yr1 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 15-16.csv')
df_yr2 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 16-17.csv')
df_yr3 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 17-18.csv')
df_yr4 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 18-19.csv')
df_yr5 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 19-20.csv')
df_yr6 = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Total Stats 20-21.csv')
df_yr1 = pd.DataFrame(df_yr1)
df_yr1
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0   Golden State Warriors*  82  19880  3489  7159  0.487  1077  2592
# 1    2.0   Oklahoma City Thunder*  82  19830  3372  7082  0.476   678  1945
# 2    3.0         Sacramento Kings  82  19805  3283  7083  0.464   660  1839
# 3    4.0         Houston Rockets*  82  19830  3094  6847  0.452   878  2533
# 4    5.0          Boston Celtics*  82  19780  3216  7318  0.439   717  2142
# 5    6.0  Portland Trail Blazers*  82  19805  3167  7040  0.450   864  2336
# 6    7.0    Los Angeles Clippers*  82  19830  3141  6759  0.465   797  2190
# 7    8.0     Cleveland Cavaliers*  82  19855  3171  6888  0.460   880  2428
# 8    9.0       Washington Wizards  82  19755  3238  7033  0.460   709  1983
# 9   10.0       San Antonio Spurs*  82  19705  3289  6797  0.484   570  1518
# 10  11.0       Charlotte Hornets*  82  19855  3036  6922  0.439   873  2410
# ...

# %%
#determine the dimensions of our dataframe
df.shape
# Out:
# (31, 25)

# %%
#determine the number of rows

df.shape[0]
# Out:
# 31

# %%
#print the last 3 rows
df.tail(3)
# Out:
#       Rk                Team   G     MP    FG   FGA    FG%   3P   3PA    3P%  \
# 28  29.0  Philadelphia 76ers  82  19805  2970  6887  0.431  764  2255  0.339
# 29  30.0  Los Angeles Lakers  82  19730  2880  6956  0.414  639  2016  0.317
# 30   NaN      League Average  82  19828  3136  6935  0.452  698  1975  0.354
#
#     ...    FT%  ORB   DRB   TRB   AST  STL  BLK   TOV    PF   PTS
# 28  ...  0.694  777  2605  3382  1765  680  495  1343  1780  7988
# 29  ...  0.781  878  2645  3523  1478  593  337  1124  1662  7982
# 30  ...  0.757  854  2734  3588  1828  643  406  1179  1662  8419
#
# [3 rows x 25 columns]

# %%
#create a python function that adds the same year to each team in the dataframe
#15-16 season
year_one_list = df_yr1['Team'].tolist()  
year1_column = []

for x in year_one_list:
    year1_column.append('15-16')
    
df_yr1['Year'] = year1_column
df_yr1

#16-17 season
year_two_list = df_yr2['Team'].tolist()  
year2_column = []

for x in year_two_list:
    year2_column.append('16-17')
    
df_yr2['Year'] = year2_column
df_yr2

#17-18 season
year_three_list = df_yr3['Team'].tolist()  
year3_column = []

for x in year_three_list:
    year2_column.append('17-18')
    
df_yr3['Year'] = year3_column
df_yr3

#18-19 season
year_four_list = df_yr4['Team'].tolist()  
year4_column = []

for x in year_four_list:
    year2_column.append('18-19')
    
df_yr4['Year'] = year4_column
df_yr4

#19-20 season
year_five_list = df_yr5['Team'].tolist()  
year5_column = []

for x in year_five_list:
    year5_column.append('19-20')
    
df_yr5['Year'] = year5_column
df_yr5

#20-21 season
year_six_list = df_yr6['Team'].tolist()  
year5_column = []

for x in year_five_list:
    year5_column.append('20-21')
    
df_yr6['Year'] = year6_column
df_yr6
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0   Golden State Warriors*  82  19880  3489  7159  0.487  1077  2592
# 1    2.0   Oklahoma City Thunder*  82  19830  3372  7082  0.476   678  1945
# 2    3.0         Sacramento Kings  82  19805  3283  7083  0.464   660  1839
# 3    4.0         Houston Rockets*  82  19830  3094  6847  0.452   878  2533
# 4    5.0          Boston Celtics*  82  19780  3216  7318  0.439   717  2142
# 5    6.0  Portland Trail Blazers*  82  19805  3167  7040  0.450   864  2336
# 6    7.0    Los Angeles Clippers*  82  19830  3141  6759  0.465   797  2190
# 7    8.0     Cleveland Cavaliers*  82  19855  3171  6888  0.460   880  2428
# 8    9.0       Washington Wizards  82  19755  3238  7033  0.460   709  1983
# 9   10.0       San Antonio Spurs*  82  19705  3289  6797  0.484   570  1518
# 10  11.0       Charlotte Hornets*  82  19855  3036  6922  0.439   873  2410
# ...

# %%
#print out the columns
df.columns
# Out:
# Index(['Rk', 'Team', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# examine the datatypes of the columns
# note that these were automatically inferred by pandas upon import!
pd.DataFrame(df.dtypes, columns=['Data Type'])
# Out:
#      Data Type
# Rk     float64
# Team    object
# G        int64
# MP       int64
# FG       int64
# FGA      int64
# FG%    float64
# 3P       int64
# 3PA      int64
# 3P%    float64
# 2P       int64
# 2PA      int64
# 2P%    float64
# FT       int64
# FTA      int64
# FT%    float64
# ORB      int64
# DRB      int64
# TRB      int64
# AST      int64
# STL      int64
# BLK      int64
# TOV      int64
# PF       int64
# PTS      int64

# %%
df['STL'] = df['STL'].astype('float')

# %%
pd.DataFrame(df.dtypes, columns=['Data Type'])
# Out:
#      Data Type
# Rk     float64
# Team    object
# G        int64
# MP       int64
# FG       int64
# FGA      int64
# FG%    float64
# 3P       int64
# 3PA      int64
# 3P%    float64
# 2P       int64
# 2PA      int64
# 2P%    float64
# FT       int64
# FTA      int64
# FT%    float64
# ORB      int64
# DRB      int64
# TRB      int64
# AST      int64
# STL    float64
# BLK      int64
# TOV      int64
# PF       int64
# PTS      int64

# %%
# displaying the index as it sits (auto-generated upon import)
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# also note that our auto-generated index has no name
print(df.index.name)
# Out:
# None

# %%
# Here we are looking at three columns;
# the one on the left is the index (automatically generated upon import by pandas)
# 'Rk' is our PK (primary key) from our imported table. 'Name' is a data column.
# Notice that the generated index starts at zero and our PK starts at 1.
pd.DataFrame(df.head(3)[['Rk', 'Team']])
# Out:
#     Rk                    Team
# 0  1.0  Golden State Warriors*
# 1  2.0  Oklahoma City Thunder*
# 2  3.0        Sacramento Kings

# %% [markdown]
# # Identify and Remove all Missing Data

# %%
# here is a quick and dirty way see all null values in aggregate
df.isnull().sum()
# Out:
# Rk      1
# Team    0
# G       0
# MP      0
# FG      0
# FGA     0
# FG%     0
# 3P      0
# 3PA     0
# 3P%     0
# 2P      0
# 2PA     0
# 2P%     0
# FT      0
# FTA     0
# FT%     0
# ORB     0
# DRB     0
# TRB     0
# AST     0
# STL     0
# BLK     0
# TOV     0
# PF      0
# PTS     0
# dtype: int64

# %%
# or we can make things pretty as follows
null_df = pd.DataFrame(df.isnull().sum(), columns=['Count of Nulls'])
null_df.index.name = 'Column'
null_df.sort_values(['Count of Nulls'], ascending=False).head(10)
# Out:
#         Count of Nulls
# Column
# Rk                   1
# FT                   0
# PF                   0
# TOV                  0
# BLK                  0
# STL                  0
# AST                  0
# TRB                  0
# DRB                  0
# ORB                  0

# %%
df['Unnamed: 27'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 27'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#dropping Unamed columns
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)
df.head()

# %%
df.shape

# %%
df.drop(df.tail(1).index,inplace=True) # drop last 1 rows
df.tail(3)

# %%
df.shape

# %% [markdown]
# # Data Visualization of NBA Data

# %%
# let's sort by steals, descending
df.sort_values(by='STL', ascending=False).head(3)

# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
# Use year data frame to 
df[['Team', 'STL']].sort_values('STL').values

# %%
# Compare with scatter plot
df.plot(kind='barh', x='Team', y='STL');

# %% [markdown]
# # Add Column for year
