# %% [markdown]
# # Exploring Data with Pandas

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\anooj\Desktop\ga-data\NBA-Playoff-Predictor\NBA Player Data\NBA Player Data.csv')
df = pd.DataFrame(df)
df
# Out:
#      Season   Lg                           Player Voting  Age   Tm   G    MP  \
# 0   2020-21  NBA           Nikola Jokić\jokicni01    (V)   25  DEN  72  34.6
# 1   2019-20  NBA  Giannis Antetokounmpo\antetgi01    (V)   25  MIL  63  30.4
# 2   2018-19  NBA  Giannis Antetokounmpo\antetgi01    (V)   24  MIL  72  32.8
# 3   2017-18  NBA           James Harden\hardeja01    (V)   28  HOU  72  35.4
# 4   2016-17  NBA      Russell Westbrook\westbru01    (V)   28  OKC  81  34.6
# ..      ...  ...                              ...    ...  ...  ...  ..   ...
# 61  1959-60  NBA       Wilt Chamberlain\chambwi01    (V)   23  PHW  72  46.4
# 62  1958-59  NBA             Bob Pettit\pettibo01    (V)   26  STL  72  39.9
# 63  1957-58  NBA           Bill Russell\russebi01    (V)   23  BOS  69  38.3
# 64  1956-57  NBA              Bob Cousy\cousybo01    (V)   28  BOS  64  36.9
# 65  1955-56  NBA             Bob Pettit\pettibo01    (V)   23  STL  72  38.8
#
# ...

# %%
#determine the dimensions of our dataframe
df.shape
# Out:
# (66, 18)

# %%
#determine the number of rows

df.shape[0]
# Out:
# 66

# %%
#print the last 3 rows
df.tail(3)
# Out:
#      Season   Lg                  Player Voting  Age   Tm   G    MP   PTS  \
# 63  1957-58  NBA  Bill Russell\russebi01    (V)   23  BOS  69  38.3  16.6
# 64  1956-57  NBA     Bob Cousy\cousybo01    (V)   28  BOS  64  36.9  20.6
# 65  1955-56  NBA    Bob Pettit\pettibo01    (V)   23  STL  72  38.8  25.7
#
#      TRB  AST  STL  BLK    FG%  3P%    FT%    WS  WS/48
# 63  22.7  2.9  NaN  NaN  0.442  NaN  0.519  11.3  0.206
# 64   4.8  7.5  NaN  NaN  0.378  NaN  0.821   8.8  0.178
# 65  16.2  2.6  NaN  NaN  0.429  NaN  0.736  13.8  0.236

# %%
pd.DataFrame(df.dtypes, columns=['Data Type'])
# Out:
#        Data Type
# Season    object
# Lg        object
# Player    object
# Voting    object
# Age        int64
# Tm        object
# G          int64
# MP       float64
# PTS      float64
# TRB      float64
# AST      float64
# STL      float64
# BLK      float64
# FG%      float64
# 3P%      float64
# FT%      float64
# WS       float64
# WS/48    float64
